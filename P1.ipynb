# %% [markdown]
# <a href="https://colab.research.google.com/github/jtiwari709/Shanker/blob/master/P1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
1+1
# Out:
# 2

# %%
print(2+3)
# Out:
# 5
